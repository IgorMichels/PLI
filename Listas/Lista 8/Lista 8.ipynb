# %% [markdown]
# # Lista 8
#
# # Dualidade
#
# Fernanda Gomes e Igor Michels

# %% [markdown]
# ## Seção 4.1
#
# ### Questão 1
#
# #### Item a
#
# Nosso problema é
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & x_1 + 3x_2 + x_3 \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       x_1 + 2x_2 + 7x_3 & \leq -3 \\
#       x_2 - x_3 & = 9 \\
#       9x_1 & \leq 5 \\
#       x_1 - x_2 + x_3 & = 0 \\
#       x_1, x_2 & \geq 0 \\
#       x_3 & \text{ livre}.
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# Cujo dual será dado por
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & -3y_1 + 9y_2 + 5y_3 \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       y_1 + 9y_3 + y_4 & \geq 1 \\
#       2y_1 + y_2 - y_4 & \geq 3 \\
#       7y_1 - y_2 + y_4 & = 1 \\
#       y_1, y_3 & \geq 0 \\
#       y_2, y_4 & \text{ livre}.
#     \end{aligned}
#   \end{split}
# \end{equation}

# %% [markdown]
# #### Item b
#
# Nosso problema é
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & 5x_1 + 6x_2 \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       3x_1 - x_2& \geq 8 \\
#       2x_1 + 4x_2 & = -2 \\
#       3x_1 + 2x_2 & \leq 2 \\
#       - x_1 + 2x_2 & = -3 \\
#       x_1 & \geq 0 \\
#       x_2 & \text{ livre}.
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# Cujo dual será dado por
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & 8y_1 - 2y_2 + 2y_3 - 3y_4 \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       3y_1 + 2y_2 + 3y_3 - y_4 & \geq 5 \\
#       - y_1 + 4y_2 + 2y_3 + 2y_4 & = 6 \\
#       y_1 & \leq 0 \\
#       y_2, y_4 & \text{ livre} \\
#       y_3 & \geq 0.
#     \end{aligned}
#   \end{split}
# \end{equation}

# %% [markdown]
# ### Questão 2
#
# #### Item a
#
# Podemos concatenar os vetores $c$ e $d$, as matrizes $A$ e $D$ e os vetores $x$ e $u$, chegando em $\tilde{c} = \begin{bmatrix} c \\ d \end{bmatrix}$, $\tilde{A} = \begin{bmatrix} A & D \end{bmatrix}$ e $\tilde{x} = \begin{bmatrix} x \\ u \end{bmatrix}$. Suponha também que a dimensão de $x$ (e consequentemente de $u$) seja $n$, então podemos formular nosso problema como
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & \tilde{c}^\top \tilde{x} \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       \tilde{A}\tilde{x} & = b \\
#       \tilde{x_i} & \geq 0 & \forall i \in \{1, \dots, n\} \\
#       \tilde{x_i} & \text{ livre} & \forall i \in \{n + 1, \dots, 2n\}.
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# Agora, podemos fazer o dual como anteriormente, ou seja, o dual é
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & b^\top y \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       A^\top y & \geq c \\
#       D^\top y & = d \\
#       y & \text{ livre}.
#     \end{aligned}
#   \end{split}
# \end{equation}

# %% [markdown]
# #### Item b
#
# Podemos seguir ideia análoga a do item anterior, concatenando as matrizes $D$ e $-I$ e os vetores $x$ e $u$, chegando em $\tilde{D} = \begin{bmatrix} D & -I \end{bmatrix}$ e $\tilde{x} = \begin{bmatrix} x \\ u \end{bmatrix}$. Suponha também que a dimensão de $x$ (e consequentemente de $u$) seja $n$, então podemos formular nosso problema como
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & c^\top x \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       Ax & \geq b \\
#       \tilde{D}\tilde{x} & \leq d \\
#       \tilde{x_i} & \leq 0 & \forall i \in \{1, \dots, n\} \\
#       \tilde{x_i} & \geq 0 & \forall i \in \{n + 1, \dots, 2n\}.
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# Agora, para fazer o dual, vamos definir $\tilde{b} = \begin{bmatrix} b \\ d \end{bmatrix}$ e $\tilde{y} = \begin{bmatrix} y_A \\ y_D \end{bmatrix}$, com dimensões apropriadas, assim o dual é
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & \tilde{b}^\top \tilde{y} \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       A^\top y_A + D^\top y_D & \leq c \\
#       - Iy_D & \geq \mathbb{0} \\
#       y_A & \leq 0 \\
#       y_D & \geq 0.
#     \end{aligned}
#   \end{split}
# \end{equation}

# %% [markdown]
# ### Questão 3
#
# #### Item a
#
# Seja $j$ tal que $a_j = \min\{a_1, \dots, a_n\}$. É fácil ver que $x = a_j$ é solução factível, pois, por definição, $a_j \leq a_i \forall i \in \{1, \dots, n\}$, assim, basta provar que é máximo. Assim, suponha que $b = a_j + l$, com $l > 0$, é solução ótima, isso é, é factível e o máximo do problema. Assim, $\forall i \in \{1, \dots, n\} ~ b \leq a_i$. Mas isso implica que $b \leq a_j \iff a_j + l \leq a_j \iff l \leq 0$, absurdo. Logo, $a_j$ é solução ótima do problema.

# %% [markdown]
# #### Item b
#
# Definindo $a = \begin{bmatrix} a_1 \\ \vdots \\ a_n \end{bmatrix}$. O dual é
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & a^\top y \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       \sum y & = 1 \\
#       y & \geq 0.
#     \end{aligned}
#   \end{split}
# \end{equation}

# %% [markdown]
# #### Item c
#
# O problema dual está escolhendo uma entrada de $y$ para ser $1$ e as demais para ser $0$, fazendo com que $a^\top y$ seja mínimo, ou seja, o dual fará $y_j = 1$, com $j$ como definido no item a.

# %% [markdown]
# ### Questão 4
#
# Podemos montar o problema (P)
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & -x_1 \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       x_1 - x_2 & \leq -1 \\
#       x_1 - x_2 & \geq 0 \\
#       x & \text{ livre}.
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# Assim o dual (D) será dado por
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & -y_1 \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       y_1 + y_2 & = -1 \\
#       - y_1 - y_2 & = 0 \\
#       y_1 & \geq 0 \\
#       y_2 & \leq 0.
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# Podemos mostrar, algebricamente, que o (P) é infactível, pois temos que $x_2 \geq x_1 + 1$ e $x_2 \leq x_1$, assim, temos que $x_1 \geq x_2 \geq x_1 + 1 \iff 0 \geq 1$, absurdo. Já para (D), podemos ver que $y_2 = -y_1$, assim, vale que $-1 = y_1 + y_2 = y_1 - y_1 = 0$, absurdo.
#
# Também podemos ver isso graficamente:

# %%
using Plots;
f(x) = x + 1;
g(x) = x;
X = -10:10;
the_max = max(f(X[end]), f(X[1]));
the_min = min(g(X[end]), g(X[1]));

plot(X, f, fill = (the_max, 0.5, :auto), label = "R1", title = "(P)");
plot!(X, g, fill = (the_min, 0.5, :auto), label = "R2")

# %%
f(x) = - x - 1;
g(x) = - x;
X = 0:10;

plot(X, f, label = "R1", title = "(D)");
plot!(X, g, label = "R2")

# %% [markdown]
# ## Seção 4.2
#
# ### Questão 1
#
# #### Item a
#
# O problema já é de maximização e as restrições quanto a $x$ já são de positividade, falta apenas tratar as restrições gerais para igualdade. Para fazer isso, basta modificar a restrição $Ax \leq b$ para $Ax + Iu = b$, onde $I$ é a identidade e $u \geq 0$ é o vetor de folgas de cada uma das restrições.

# %% [markdown]
# #### Item b
#
# Usando a mesma ideia da questão 2a da seção 4.1, com $D = I$, podemos concatenar as matrizes $A$ e $I$, chegando em $\tilde{A} = \begin{bmatrix} A & I \end{bmatrix}$. Também definimos $\tilde{c} = \begin{bmatrix} c \\ \mathbb{0} \end{bmatrix}$, com $\mathbb{0}$ sendo um vetor de zeros. Assim o dual é
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & b^\top y \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       \tilde{A}^\top y & \geq \tilde{c} \\
#       y & \text{ livre}.
#     \end{aligned}
#   \end{split}
# \end{equation}

# %% [markdown]
# #### Item c
#
# Temos que, em (P'), vale que $x' = \begin{bmatrix} x \\ u \end{bmatrix}$, assim, como $x$ é solução de (P), temos que as primeiras entradas de $x'$ devem ser iguais as de $x$. As últimas entradas de $x'$ são referentes ao vetor $u$, dado por $b - Ax$. Assim, temos que $x' = \begin{bmatrix} x \\ b - Ax \end{bmatrix}$.

# %% [markdown]
# #### Item d
#
# Usando diretamente o Teorema, sai que, como $x'$ é solução ótima de (P'), existe um $y'$ que é solução ótima de (D') e que possui o mesmo valor, em (D'), que $x'$ possui em (P').

# %% [markdown]
# ## Seção 4.3
#
# ### Questão 1
#
# #### Item a
#
# - Primeiramente, vamos achar o dual:
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & 5y_1 + 7y_2 \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       y_1 - y_2 & \leq -2 \\
#       3y_1 + 4y_2 & \geq -1 \\
#       2y_1 + 2y_2 & = 0 \\
#       y_1 & \leq 0 \\
#       y_2 & \geq 0.
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# - O Complementary Slackness de (P) é dado por
#
# \begin{equation}
#   \begin{bmatrix}
#     5 - (x_1 + 3x_2 + 2x_3) \\
#     7 - (-x_1 + 4x_2 + 2x_3)
#   \end{bmatrix}.
# \end{equation}
#
# - Já o Complementary Slackness de (D) é
#
# \begin{equation}
#   \begin{bmatrix}
#     - 2 - (y_1 - y_2) \\
#     - 1 - (3y_1 + 4y_2) \\
#     0 - (2y_1 + 2y_2)
#   \end{bmatrix}.
# \end{equation}
#
# - É fácil ver que tanto $\overline{x} = \begin{bmatrix} -1 \\ 0 \\ 3 \end{bmatrix}$ quanto $\overline{y} = \begin{bmatrix} -1 \\ 1 \end{bmatrix}$ são soluções factíveis para (P) e (D), respectivamente. Também podemos ver que $\begin{bmatrix} -2 & -1 & 0 \end{bmatrix}\overline{x} = 2$ e que $\begin{bmatrix} 5 & 7 \end{bmatrix}\overline{y} = 2$. Como (P) e (D) são um par primal-dual, com respectivos vetores que produzem o mesmo valor na função objetivo, temos que tais vetores são soluções ótimas.
#
# - Usando CS, podemos ver que
# $$5 - (x_1 + 3x_2 + 2x_3) = 0$$
# $$7 - (-x_1 + 4x_2 + 2x_3) = 0$$
# $$-2 - (y_1 - y_2) = 0$$
# $$x_2 = 0$$
# $$0 - (2y_1 + 2y_2) = 0.$$

# %% [markdown]
# #### Item b
#
# - Primeiramente, vamos achar o dual:
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & 3y_1 + 9y_2 + 2y_3 \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       y_1 + 4y_2 + 7y_3 & \geq -5 \\
#       2y_1 + 5y_2 + 8y_3 & \geq -7 \\
#       3y_1 + 6y_2 + 9y_3 & \geq -5 \\
#       y_1, y_2 & \geq 0 \\
#       y_3 & \leq 0.
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# - O Complementary Slackness de (P) é dado por
#
# \begin{equation}
#   \begin{bmatrix}
#     3 - (x_1 + 2x_2 + 3x_3) \\
#     9 - (4x_1 + 5x_2 + 6x_3) \\
#     2 - (7x_1 + 8x_2 + 9x_3)
#   \end{bmatrix}.
# \end{equation}
#
# - Já o Complementary Slackness de (D) é
#
# \begin{equation}
#   \begin{bmatrix}
#     - 5 - (y_1 + 4y_2 + 7y_3) \\
#     - 7 - (2y_1 + 5y_2 + 8y_3) \\
#     - 5 - (3y_1 + 6y_2 + 9y_3)
#   \end{bmatrix}.
# \end{equation}
#
# - É fácil ver que tanto $\overline{x} = \begin{bmatrix} 1 \\ 1 \\ 0 \end{bmatrix}$ quanto $\overline{y} = \begin{bmatrix} -1 \\ -1 \\ 0 \end{bmatrix}$ são soluções factíveis para (P) e (D), respectivamente. Também podemos ver que $\begin{bmatrix} -5 & -7 & -5 \end{bmatrix}\overline{x} = -12$ e que $\begin{bmatrix} 3 & 9 & 2 \end{bmatrix}\overline{y} = -12$. Como (P) e (D) são um par primal-dual, com respectivos vetores que produzem o mesmo valor na função objetivo, temos que tais vetores são soluções ótimas.
#
# - Usando CS, podemos ver que
# $$3 - (x_1 + 2x_2 + 3x_3) = 0$$
# $$9 - (4x_1 + 5x_2 + 6x_3) = 0$$
# $$x_3 = 0$$
# $$-5 - (y_1 + 4y_2 + 7y_3) = 0$$
# $$-7 - (2y_1 + 5y_2 + 8y_3) = 0$$
# $$y_3 = 0.$$

# %% [markdown]
# ## Seção 4.4
#
# ### Questão 1
#
# #### Item a
#
# Suponha que existe $x \geq \mathbb{0}$ tal que $Ax \leq b$. Note que se existir $y \geq \mathbb{0}$ tal que $A^\top y \geq \mathbb{0}$ e $b^\top y < 0$ teremos que $y^\top Ax \leq y^\top b$, assim $(A^\top y)^\top x \leq b^\top y$, onde o lado esquerdo é todo não negativo, resultando num valor não negativo e o lado direito é negativo, o que nos dá um absurdo.
#
# Dessa forma, provamos que não podemos ter os dois ao mesmo tempo e, em especial, provamos que se a primeira sentença vale, a segunda não pode ser verdadeira. Agora, suponha que a primeira sentença é falsa. Dessa forma, o problema
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & \mathbb{0}^\top x \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       Ax & \leq b \\
#       x & \geq \mathbb{0}
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# é infactível. Com isso, seu dual
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & b^\top y \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       A^\top y & \geq \mathbb{0} \\
#       y & \geq \mathbb{0}
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# é infactível ou ilimitado. Podemos ver que o problema dual é factível pois $A^\top \mathbb{0} \geq \mathbb{0}$, logo, ele é ilimitado. Dessa forma, teremos algum valor de $y$ de modo que $A^\top y \geq \mathbb{0}$, $y \geq \mathbb{0}$ e $b^\top y < 0$.

# %% [markdown]
# #### Item b
#
# Suponha que existe $x \neq \mathbb{0}$ tal que $Ax = \mathbb{0}$. Note que se existir $y$ tal que $A^\top y > \mathbb{0}$ teremos que $y^\top Ax = y^\top \mathbb{0} = 0$, assim $(A^\top y)^\top x = 0$. Como $x \geq \mathbb{0}$ e $x \neq \mathbb{0}$, então temos que $(A^\top y)^\top = \mathbb{0}$, ou seja, $A^\top y = \mathbb{0}$, absurdo.
#
# Dessa forma, provamos que não podemos ter os dois ao mesmo tempo e, em especial, provamos que se a primeira sentença vale, a segunda não pode ser verdadeira. Agora, suponha que a primeira sentença é falsa. Dessa forma, temos que $\forall x \neq \mathbb{0}, ~ Ax \neq \mathbb{0} \lor \neg (x \geq \mathbb{0})$. Em particular, temos que se $x \geq \mathbb{0}$, vale que $Ax = \mathbb{0} \iff x = \mathbb{0}$. Assim, o problema primal
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & \mathbb{1}^\top x \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       Ax & = \mathbb{0} \\
#       x & \geq \mathbb{0}
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# é factível com ótimo igual $0$ em $x = \mathbb{0}$. Com isso, seu dual
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & \mathbb{0}^\top y \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       A^\top y & \geq \mathbb{1}
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# também é factível. Logo, existe $y$ tal que $A^\top y \geq \mathbb{1} > \mathbb{0}$.

# %% [markdown]
# #### Item c
#
# Note que fazendo $\tilde{A} = \begin{bmatrix} A \\ A' \\ -A' \end{bmatrix}$ e $\tilde{b} = \begin{bmatrix} b \\ b' \\ -b' \end{bmatrix}$ temos que o enunciado é equivalente a termos exatamente uma das sentenças abaixo sendo verdadeira
#
#  - Existe $x$ tal que $\tilde{A}x \leq \tilde{b}$ tem solução ou;
#  - Existe $y \geq \mathbb{0}$ tal que $\tilde{A}^\top y = \mathbb{0}$ e $b^\top y < 0$.
#
# Note que provar que isso não pode ser simultaneamente verdade é simples, pois da primeira sentença podemos ver que $y^\top (Ax - b) \leq 0$, enquanto a segunda nos leva que $y^\top (Ax - b) > 0$.
#
# Além disso, podemos ver que a segunda sentença é um certificado de infactibilidade para $Ax \leq b$, ou seja, se a primeira sentença não for válida, a segunda necessariamente é.

# %% [markdown]
# #### Item d
#
# Suponha que ambas as sentenças sejam verdadeiras. Assim, temos que $y^\top Ax + y^\top A'x' = y^\top b$. Mas note que, dessa forma, o lado direito da equação é negativo e o esquerdo é não negativo, absurdo. Logo, as duas sentenças não podem ser verdadeiras ao mesmo tempo.
#
# Agora, suponha que a primeira sentença seja falsa. Desse modo, fazendo $\tilde{A} = \begin{bmatrix} A & A' & -A' \end{bmatrix}$ e $\tilde{x} = \begin{bmatrix} x \\ x' \\ -x' \end{bmatrix}$, temos que o problema
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & \mathbb{0}^\top \tilde{x} \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       \tilde{A}\tilde{x} & = b \\
#       \tilde{x} & \geq \mathbb{0}
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# é infactível. Seu dual,
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & b^\top y \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       \tilde{A}^\top y & \geq \mathbb{0}
#     \end{aligned}
#   \end{split}
# \end{equation}
#
# é ilimitado, pois $y = \mathbb{0}$ é uma solução factível. Logo, temos que existe $y$ tal que $y^\top b < 0$, $A^\top y \geq \mathbb{0} \implies y^\top A \geq \mathbb{0}$ e que $y^\top A' = \mathbb{0}$, pois $A'^\top y \geq \mathbb{0}$ e $- A'^\top y \geq \mathbb{0}$.

# %% [markdown]
# # Dualidade em Grafos
#
# ## Corretude do st-path
#
# Seja $G = (V, E)$ um grafo com nós $s$ e $t$ distintos e $c_e > 0 ~ \forall e \in E$, ou seja, toda aresta tem um comprimento positivo. Seja $P$ um st-path, devemos mostrar que $P$ corresponde a uma solução factível $x$ do problema (1.34). Para isso, vamos fazer $x_e = 1$ se $e \in P$ e $x_e = 0$ caso contrário. Pelo Remark 1.1, todo corte-st $\delta(U)$ contém uma aresta de $P$, assim vale que $\sum_{e \in \delta(U)} x_e \geq 1$, o que implica que $x$ é uma solução factível.
#
# Agora, devemos mostrar que toda solução ótima $\overline{x}$ é um st-path. Definindo $S = \{e \in E : x_e = 1\}$, temos que, pelo Remark 1.2, $S$ contém um st-path. Se $S = P$, chegamos onde queríamos. Se não, definimos $x'$ tal que $x'_e = 1$ se $e \in P$ e $x'_e = 0$ caso contrário, que também é solução factível (fato demonstrado no parágrafo anterior) mas que tem um custo menor que o custo de $S$, logo, $\overline{x}$ não pode ser solução ótima, o que é um absurdo. Disso segue que $S$ deve ser um st-path.

# %% [markdown]
# ## Seção 1.5.2
#
# ### Questão 2
#
# #### Item a
#
# A formulação geral será dada no item b, no item a iremos realizar a implementação da mesma.

# %%
using GLPK, JuMP;

arestas = [1 2; 1 4; 1 6; 2 3; 2 4; 2 5; 2 7
           3 5; 3 8; 4 6; 4 7; 5 7; 6 7; 7 8];

nodes = maximum(arestas);
edges = size(arestas, 1);
A = zeros(Int64, edges, nodes);
for i in 1:edges
    A[i, arestas[i, 1]] = 1;
    A[i, arestas[i, 2]] = 1;
end

model = Model(GLPK.Optimizer);
@variable(model, x[i = 1:nodes] >= 0, base_name = "x", Int);
opt_function = @expression(model, ones(nodes)'*x);
@constraint(model, C, A*x .>= ones(edges));
@objective(model, Min, opt_function);

status = JuMP.optimize!(model);
xstar = value.(x);
print("Nodes: ");
for i in 1:nodes
    if xstar[i] == 1
        print(i, " ");
    end
end
# Out:
# Nodes: 1 3 4 5 7

# %% [markdown]
# #### Item b
#
# Como visto na implementação acima, a ideia do caso geral é gerar uma matriz $A$, onde cada linha representa uma aresta e as colunas representam os nós, assim a entrada $a_{i, j}$ será $1$ se o nó $j$ é extremo da aresta $i$. O vetor $x$ será um vetor de inteiros (ou binário, pois queremos minimizar) do $\mathbb{R}^n$, sendo $n$ o número de nós do grafo. O conjunto de interesse será dado pelas entradas não nulas de $x$, assim, para garantir que cada aresta tenha pelo menos uma de suas extremidades no conjunto devemos ter que $Ax \geq \mathbb{1}$.
#
# Queremos a menor quantidade possível de nós no conjunto, então devemos minimizar $x^\top \mathbb{1}$, assim, nosso problema é dado por
#
# \begin{equation}
#   \begin{split}
#     \text{min }  & x^\top \mathbb{1} \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       Ax & \geq \mathbb{1} \\
#       x & \geq \mathbb{0}.
#     \end{aligned}
#   \end{split}
# \end{equation}

# %% [markdown]
# ## Seção 3.1.3
#
# ### Exercício 1
#
# #### Item a
#
# Utilizando as mesmas convenções da questão anterior (acima), podemos ver que o dual é
#
# \begin{equation}
#   \begin{split}
#     \text{max }  & y^\top \mathbb{1} \\
#     \text{sujeito a } &
#     \begin{aligned}[t]
#       A^\top y & \leq \mathbb{1} \\
#       y & \geq \mathbb{0}.
#     \end{aligned}
#   \end{split}
# \end{equation}

# %% [markdown]
# #### Item b
#
# Dentro de um grafo, um matching é um conjunto de arestas $M$ de modo que, para cada vértice $v$ do grafo, no máximo uma aresta de $M$ incide em $v$. O tamanho de um conjunto é a quantidade de elementos desse conjunto, assim, o tamaho do matching de um grafo é a quantidade de arestas desse matching.
#
# Note que o dual (D) está buscando exatamente isso, o tamanho máximo de um matching do grafo $G$, uma vez que $A$ é uma matriz onde as linhas corresponde as arestas e as colunas aos vértices, assim, sua transposta inverte essa relação. Já $y$ faz referência as arestas do grafo, assim, $y \geq \mathbb{0}$ pode ser interpretado como se a aresta entra no conjunto ou não e $A^\top y$ como a quantidade de vezes que um vértice é atingido pelas arestas escolhidas. Note que fazendo $A^\top y \leq \mathbb{1}$ garantimos que o conjunto é um matching.
#
# Agora, usando o Teorema 3.2, segue que (D) é lower bound de (P) e, usando as interpretações de (D) e (P), temos a prova do item.

# %% [markdown]
# #### Item c
#
# Tome o $K_5$. É fácil ver que o vertex-cover desse grafo tem cardinalidade $4$, caso contrário a aresta que conecta dois dos vértices não escolhidos não foi coberta. Por outro lado, todos os matchings tem tamanho, no máximo, $2$, pois se considerarmos um matching de tamanho $3$ estaremos atingindo $6$ nós, assim, pelo PCP, um nó será atingido mais de uma vez. Além disso, temos que a solução ótima de (P) é $4$ e de (D) é $2.5$:

# %%
arestas = [1 2; 1 3; 1 4; 1 5; 2 3;
           2 4; 2 5; 3 4; 3 5; 4 5];

nodes = maximum(arestas);
edges = size(arestas, 1);
A = zeros(Int64, edges, nodes);
for i in 1:edges
    A[i, arestas[i, 1]] = 1;
    A[i, arestas[i, 2]] = 1;
end

model = Model(GLPK.Optimizer);
@variable(model, x[i = 1:nodes] >= 0, base_name = "x", Int);
opt_function = @expression(model, ones(nodes)'*x);
@constraint(model, C, A*x .>= ones(edges));
@objective(model, Min, opt_function);

status = JuMP.optimize!(model);
xstar = value.(x);
println("Solução ótima de (P): ", sum(xstar));

model = Model(GLPK.Optimizer);
@variable(model, y[i = 1:edges] >= 0, base_name = "y");
opt_function = @expression(model, ones(edges)'*y);
@constraint(model, C, A'*y .<= ones(nodes));
@objective(model, Max, opt_function);

status = JuMP.optimize!(model);
ystar = value.(y);
println("Solução ótima de (D): ", sum(ystar));
# Out:
# Solução ótima de (P): 4.0
# Solução ótima de (D): 2.5
